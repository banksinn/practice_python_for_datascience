# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
my_df = {"day" : ["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],
               "temperature (celcius)" : [6,8,6,8,10,8,6]
}
df = pd.DataFrame(my_df)
x = df["day"]
y = df["temperature (celcius)"]
plt.plot(x,y)
plt.savefig("LineGraphs01.png") #ต้อง save ก่อน show เสมอ
plt.show()

# %%
data = [10,20,15,25,30]
plt.plot(data)
plt.show()

# %%
plt.plot(data,linewidth=0.8,linestyle="--",marker="o",ms=10,mec="red",mfc="yellow") #ms=markersize, mec=market edge color, mfc=market face color
plt.show()

# %%
plt.plot(data,"s-.r") #"marker|line|color"
plt.show()

# %%
plt.plot(data,"s-.r",linewidth=0.8,ms=10,mec="red",mfc="yellow")
plt.show()

# %%
my_df = {"day" : ["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],
               "temperature (celcius)" : [6,8,6,8,10,8,6]
}
df = pd.DataFrame(my_df)
x = df["day"]
y = df["temperature (celcius)"]
plt.plot(x,y,linestyle="-",linewidth=0.8)
plt.title("Temperature around this week (Celcius)")
plt.xlabel("Day")
plt.ylabel("Temperature")
plt.xticks(rotation=65) #xticks และ yticks ทำได้ทั้งให้หมุนและกำหนดค่าในแกน
plt.yticks(np.arange(5,15,1))
plt.show()

# %%
my_df = {"day" : ["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],
               "temp_week1" : [6,8,6,8,10,8,6],
               "temp_week2" : [8,6,6,6,9,6,8]
        }
df = pd.DataFrame(my_df)
x = df["day"]
y1 = df["temp_week1"]
y2 = df["temp_week2"]
plt.title("Temperature 2 weeks (Celcius)")
plt.xlabel("Day")
plt.ylabel("Temperature")
plt.plot(x,y1,color="r")
plt.plot(x,y2,color="b")
plt.show()

# %%
my_df = {"day" : ["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],
               "temp_week1" : [6,8,6,8,10,8,6],
               "temp_week2" : [8,6,6,6,9,6,8],
               "temp_week3" : [10,9,10,8,7,9,8],
               "temp_week4" : [6,6,9,6,6,9,8]
        }
df = pd.DataFrame(my_df)
x = df["day"]
y1 = df["temp_week1"]
y2 = df["temp_week2"]
y3 = df["temp_week3"]
y4 = df["temp_week4"]
# สร้าง axes 4 ตัวบน figure แบ่งเป็น 2 แถว 2 คอลัมน์
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(5,5), sharey=True)
# พล็อตกราฟแถวที่ 1 คอลัมน์ 1
ax[0,0].plot(x,y1,color="r")
ax[0,0].set_ylabel("Temperature")
# พล็อตกราฟแถวที่ 1 คอลัมน์ 2
ax[0,1].plot(x,y2,color="g")
# พล็อตกราฟแถวที่ 2 คอลัมน์ 1
ax[1,0].plot(x,y3,color="b")
ax[1,0].set_xlabel("Day")
ax[1,0].set_ylabel("Temperature")
# พล็อตกราฟแถวที่ 2 คอลัมน์ 2
ax[1,1].plot(x,y4,color="c")
ax[1,1].set_xlabel("Day")
# เซ็ตค่า title ของแต่ละ axes
ax[0,0].set_title("week1")
ax[0,1].set_title("week2")
ax[1,0].set_title("week3")
ax[1,1].set_title("week4")
# เซ็ตค่าของ figure
plt.suptitle("Temperature on December (Celcius)")
# ปรับการพล็อตกราฟของ subplots ให้พอดีกับพื้นที่ของ figure
fig.tight_layout()
plt.show()

# %%
my_df = {"day" : ["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],
               "temp_week1" : [6,8,6,8,10,8,6],
               "temp_week2" : [8,6,6,6,9,6,8],
               "temp_week3" : [10,9,10,8,7,9,8],
               "temp_week4" : [6,6,9,6,6,9,8]
        }
df = pd.DataFrame(my_df)
x = df["day"]
y1 = df["temp_week1"]
y2 = df["temp_week2"]
y3 = df["temp_week3"]
y4 = df["temp_week4"]
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(8,8), sharey=True)
ax[0,0].plot(x,y1,color="r",label="Temperature")
ax[0,0].legend(loc=2)
ax[0,1].plot(x,y2,color="g",label="Temperature")
ax[0,1].legend(loc="lower left")
ax[1,0].plot(x,y3,color="b",label="Temperature")
ax[1,0].legend(loc=10)
ax[1,1].plot(x,y4,color="c",label="Temperature")
ax[1,1].legend(loc="best")
ax[0,0].set_title("week1")
ax[0,1].set_title("week2")
ax[1,0].set_title("week3")
ax[1,1].set_title("week4")
plt.suptitle("Temperature on December (Celcius)")
fig.tight_layout()
plt.show()

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
x = [1,2,3]
y = [1,4,9]
plt.style.use("seaborn")
plt.figure(figsize=[5,5],dpi=60)
plt.plot(x,y)
plt.show()

# %%
my_df = {"day" : ["อาทิตย์","จันทร์","อังคาร","พุธ","พฤหัส","ศุกร์","เสาร์"],
               "temperature" : [6,8,6,8,10,8,6]
        }
df = pd.DataFrame(my_df)
x = df["day"]
y = df["temperature"]
plt.style.use("seaborn")
plt.plot(x,y,linestyle="-.",linewidth=2,marker="o")
plt.title("อุณหภูมิตลอดสัปดาห์",fontname="Tahoma",fontsize=20)
plt.xlabel("วัน",fontname="Tahoma",fontsize=16)
plt.ylabel("อุณหภูมิ (เซลเซียส)",fontname="Tahoma",fontsize=16)
plt.xticks(rotation=360,fontname="Tahoma",fontsize=12)
plt.yticks(np.arange(5,15,1),fontsize=12)
plt.show()

# %%
my_df = {"day" : ["อาทิตย์","จันทร์","อังคาร","พุธ","พฤหัส","ศุกร์","เสาร์"],
               "temperature" : [6,8,6,8,10,8,6]
        }
df = pd.DataFrame(my_df)
x = df["day"]
y = df["temperature"]
plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.sans-serif"] = "Tahoma"
plt.rcParams["font.size"] = 16
plt.plot(x,y,linestyle="-.",linewidth=2,marker="o")
plt.title("อุณหภูมิตลอดสัปดาห์")
plt.xlabel("วัน")
plt.ylabel("อุณหภูมิ (เซลเซียส)")
plt.xticks(rotation=360)
plt.yticks(np.arange(5,15,1))
plt.show()

# %%
my_df = {"month" : ["มกราคม","กุมภาพันธ์","มีนาคม"],
               "sales" : [20000,25000,90000]
     }
df = pd.DataFrame(my_df)
x = df["month"]
y = df["sales"]
plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.sans-serif"] = "Tahoma"
plt.style.use("ggplot")
plt.bar(x,y,align="edge",alpha=0.3) #align="edge" width เป็น + ชิดซ้าย เป็น - ชิดขวา align="center" ตรงกลาง
plt.title("ยอดขายรถยนต์ ไตรมาสที่ 1 พ.ศ.2564")
plt.xlabel("เดือน")
plt.ylabel("ยอดขาย (คัน)")
plt.show()

# %%
plt.bar(x,y,width=0.2,align="edge",color="c",edgecolor="b",linestyle="--",linewidth=2)
# Out:
# <BarContainer object of 3 artists>

# %%
print('hello')
# Out:
# hello

# %%
sales_data = {"year" : ["2019","2020","2021","2022"],
                     "Toyota" : [20000,25000,75000,80000],
                     "Honda" : [55000,40000,65000,50000],
                     "Mazda" : [60000,30000,22000,40000],
                     "Nissan" : [42000,58000,32500,44000]
}
df = pd.DataFrame(sales_data, columns=["year","Toyota","Honda","Mazda","Nissan"])
# กำหนดความกว้างของแท่งกราฟ
bw = 0.15
bar1 = df["Toyota"]
bar2 = df["Honda"]
bar3 = df["Mazda"]
bar4 = df["Nissan"]
pos1 = np.arange(len(df["Toyota"]))
pos2 = [x + bw for x in pos1]
pos3 = [x + bw for x in pos2]
pos4 = [x + bw for x in pos3]
plt.figure(figsize=[10,5])
plt.bar(pos1, bar1, color="red", width=bw, label="Toyota") # pos=ตำแหน่ง, bar=ค่า
plt.bar(pos2, bar2, color="green", width=bw, label="Honda")
plt.bar(pos3, bar3, color="blue", width=bw, label="Mazda")
plt.bar(pos4, bar4, color="cyan", width=bw, label="Nissan")
plt.xlabel("ปี",fontname="Tahoma",fontsize=12)
plt.xticks([r + bw for r in range(len(bar1))], df["year"]) # xticks(ตำแหน่ง, ค่า)
plt.ylabel("ยอดขาย (คัน)",fontname="Tahoma",fontsize=12)
plt.legend()
plt.show()

# %%
my_df = {"social_media" : ["Facebook","Instagram","Twitter","Tiktok","Youtube","Line"],
               "%used" : [95,65,55,80,75,85]
        }
df = pd.DataFrame(my_df)
plt.figure(figsize=[8,5])
plt.barh(df["social_media"], df["%used"]) # x อยู่ใต้แท่งกราฟ (แกน y) y ค่ากราฟ (แกน x)
plt.style.use("seaborn-deep")
plt.xticks(np.arange(0,100,10))
plt.xlabel("social media platform")
plt.ylabel("used")
plt.title("Summary %used of social media platform")
# Out:
# Text(0.5, 1.0, 'Summary %used of social media platform')

# %%
my_df = {"Quarter" : ["Q1","Q2","Q3","Q4"],
               "SalesOfProd1" : [60000,80000,125000,78500],
               "SalesOfProd2" : [93650,35300,47550,38550]
}
df = pd.DataFrame(my_df)
plt.figure(figsize=[10,8])
plt.grid()
plt.plot(df["Quarter"],df["SalesOfProd1"],marker="s",ls="-.",lw=3,ms=10,mec="blue",mfc="cyan",label="product1")
plt.plot(df["Quarter"],df["SalesOfProd2"],color="red",marker="*",ls="--",lw=3,ms=15,mfc="#E8CCD7",label="product2")
plt.xticks(rotation=45)
plt.yticks(np.arange(30000,130000,5000))
plt.legend(loc="lower left")
plt.xlabel("Quarter")
plt.ylabel("Sales")
plt.title("Sales per quarter")
plt.show()

# %%
my_df = {"Year" : ["2019","2020","2021","2022","2023"],
               "NotebookA1" : [20,22,25,20,18],
               "NotebookA2" : [30,40,30,35,40],
               "NotebookA3" : [15,10,26,23,27]
}
df = pd.DataFrame(my_df, columns= ["Year","NotebookA1","NotebookA2","NotebookA3"])
plt.stackplot(df["Year"],df["NotebookA1"],df["NotebookA2"],df["NotebookA3"],colors=["#0000FF","#FFA500","#00FF00"])
plt.show()

# %%
my_df = {"sales" : [25550.49,35000.50,50020.85,20000.00,15490.75],
               "cost" : [400,500,800,350,550]
}
my_index = ["น้ำหอม","กระเป๋า","รองเท้า","เสื้อผ้าบุรุษ","เสื้อผ้าสตรี"]
df = pd.DataFrame(my_df,index=my_index)
plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.sans-serif"] = "Tahoma"
plt.rcParams["font.size"] = 16
plt.pie(df["sales"],labels=my_index)
plt.show()

# %%
my_df = {"sales" : [25550.49,35000.50,50020.85,20000.00,15490.75],
               "cost" : [400,500,800,350,550]
}
my_index = ["น้ำหอม","กระเป๋า","รองเท้า","เสื้อผ้าบุรุษ","เสื้อผ้าสตรี"]
my_explode = [0.3,0,0,0,0]
my_colors = ["pink","orange","red","green","blue"]
df = pd.DataFrame(my_df,index=my_index)
plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.sans-serif"] = "Tahoma"
plt.rcParams["font.size"] = 16
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
ax[0].pie(df["sales"], labels=my_index, autopct="%0.2f%%")
ax[1].pie(df["sales"], labels=my_index, autopct="%d%%", colors=my_colors, explode=my_explode, shadow=1, counterclock=0, startangle=90)
plt.show()

# %%
my_df = {"math_score" : [40,45,50,65,60],
               "science_score" : [60,70,80,90,100],
               "eng_score" : [50,60,75,78,88],
               "thai_score" : [79,70,75,80,72]
}
df = pd.DataFrame(my_df, index=["std1","std2","std3","std4","std5"])
data = [df["math_score"], df["science_score"], df["eng_score"], df["thai_score"]]
plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.sans-serif"] = "Tahoma"
plt.rcParams["font.size"] = 12
my_labels = ["คณิต","วิทย์","อังกฤษ","ไทย"]
plt.boxplot(data,vert=False,widths=0.2,labels=my_labels) #widths = ความกว้างของ boxplot
plt.show()

# %%
my_df = {"math_score" : [40,45,50,65,60],
               "science_score" : [60,70,80,90,100],
               "eng_score" : [50,60,75,78,88],
               "thai_score" : [79,70,75,80,72]
}
df = pd.DataFrame(my_df, index=["std1","std2","std3","std4","std5"])
data = [df["math_score"], df["science_score"], df["eng_score"], df["thai_score"]]
plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.sans-serif"] = "Tahoma"
plt.rcParams["font.size"] = 12
my_labels = ["คณิต","วิทย์","อังกฤษ","ไทย"]
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot1 = ax1.boxplot(data, vert=True, patch_artist=True, labels=my_labels) #patch_artist = เทสีน้ำเงินลง boxplot
ax1.set_title("box plot แบบ rectangle")
bplot2 = ax2.boxplot(data, vert=True, patch_artist=True, notch=True, labels=my_labels)
ax2.set_title("box plot แบบ notch")
my_colors = ["yellow","lightgreen","lightblue","pink"]  # วิธีใส่สีให้ boxplot
for bplot in (bplot1,bplot2):
    for patch, color in zip(bplot["boxes"], my_colors):
        patch.set_facecolor(color)
plt.show()

# %%
data = {"shop" : ["shop1","shop2","shop3","shop4","shop5","shop6","shop7","shop8"],
            "advertisement_cost" : [1500,10000,3000,5500,500,9000,7500,2500],
            "revenue" : [50000,60000,30000,100000,35000,25000,80000,45550],
            "branch" : [10,18,5,25,8,1,22,9]
}
df = pd.DataFrame(data)
plt.style.use("seaborn-whitegrid")
plt.scatter(x=df["branch"], y=df["revenue"], marker="o", s=60, c="white", edgecolors="blue", linewidth=3) #s = ขนาดของตัวเน้นจุดพิกัด c=สีของจุดพิกัด
plt.xlabel("number of branch")
plt.ylabel("revenue")
plt.show()

# %%
data = {"latitude":[13.111321,13.111322,13.111323,13.111324,
                            13.111325,13.111326,13.111327,13.111328,
                            13.111329,13.111330,13.121321,13.121322,
                            13.121323,13.121324,13.121325,13.121326,
                            13.121327,13.121328,13.121329,13.121330,
                            13.911321,13.911322,13.911323,13.911324,
                            13.911325],
             "longitude":[100.119801,100.119802,100.119803,
                               100.119804,100.119805,100.119806,
                               100.119807,100.119808,100.119809,
                               100.119810,100.129801,100.129802,
                               100.129803,100.129804,100.129805,
                               100.129806,100.129807,100.129808,
                               100.129809,100.129810,100.508838,
                               100.498838,100.488838,100.478838,
                               100.468838],
             "place":["zone a1","zone a2","zone a3","zone a4",
                          "zone a5","zone a6","zone a7","zone a8",
                          "zone a9","zone a10","zone a11","zone a12",
                          "zone a13","zone a14","zone a15","zone a16",
                          "zone a17","zone a18","zone a19","zone a20",
                          "zone b1","zone b2","zone b3","zone b4",
                          "zone b5"]
       }
df = pd.DataFrame(data)
plt.hexbin(x=df["latitude"], y=df["longitude"], gridsize=10, edgecolors="red", cmap="Greens") #cmap = colormap สีของข้อมูลใน hexagon
plt.xlabel("latitude")
plt.ylabel("longtitude")
bar = plt.colorbar()
bar.set_label("frequency")
plt.show()

# %%
import seaborn as sb
data = {"female_height":[160,165,149,150,170,168,170,166,160,162,
                                     148,145,160,163,165,168,166,150,155,158,
                                     153,152,160,160,165,168,165,148,149,158,
                                     159,160,160,160,162,164,163,160,159,154,
                                     155,170,170,150,145,168,166,163,152,153,
                                     149,149,145,142,150,153,158,155,160,160,
                                     165,160,163,162,159,158,163,164,169,168],
             "male_height":[170,175,179,170,170,178,170,176,170,172,
                                    178,175,180,183,185,178,176,170,168,178,
                                    173,172,170,170,175,168,175,178,169,168,
                                    169,170,170,170,182,174,173,180,179,184,
                                    185,170,170,170,175,168,166,173,172,173,
                                    179,179,175,172,170,173,168,165,165,168,
                                    181,170,173,172,179,178,173,181,182,178]
       }
df = pd.DataFrame(data)
plt.figure(figsize = (5,5))
sb.kdeplot(x=df["female_height"], bw_adjust=0.5, fill=True, color="Pink", alpha=1)
sb.kdeplot(x=df["male_height"], bw_adjust=0.5, fill=False, color="Red")
plt.xlabel("height")
plt.legend(["male_height","female_height"])
plt.show()
